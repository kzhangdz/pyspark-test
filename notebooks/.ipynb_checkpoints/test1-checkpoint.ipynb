# %%
# Pyspark is a library that allows us to communicate with Apache Spark
# Apache Spark allows parallel processing of large scale data
# In this example, we will only use a single session/thread.
import pyspark

# %%
from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder.appName('test1').getOrCreate()

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://1f22e0b54887:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.5.0</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>test1</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
# read the dataset
spark.read.option('header', 'true').csv('test1.csv').show()
# Out:
# ++
# ||
# ++
# ++
